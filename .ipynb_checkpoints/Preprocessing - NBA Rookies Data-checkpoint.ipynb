# %% [markdown]
# # Scraping and cleaning NBA Rookies data from 2019

# %% [markdown]
# ## Initial scraping and cleaning

# %%
# important imports for data processing & visualization
import numpy as np
import pandas as pd

# imports for Web Scraping
from bs4 import BeautifulSoup  # HTML data structure
from urllib.request import urlopen  # Web client

# %%
page_url = 'https://www.basketball-reference.com/draft/NBA_2019.html'

# opens the connection and downloads html page from url
uClient = urlopen(page_url)


# parses html into a soup data structure to traverse html as if it were a json data type.
page_soup = BeautifulSoup(uClient.read())
uClient.close()

# use findALL() to get the column headers
headerRowHTML = page_soup.findAll('tr', limit =3)

# %% [markdown]
# Based on the output below, the 'tr' tag contains the 'th' tag where the name of each column is stored. We're looking at the [0] index because the 'tr' tag applies to every row, not just the header row

# %%
# use getText()to extract the text we need into a list
headers = [th.getText() for th in page_soup.findAll('tr', limit=2)[1].findAll('th')]

# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]

# %% [markdown]
# Now we're going to run the previous code for every row on the data table (excluding the first which we have as the header already)

# %%
#list comprehension creates list of lists with each inner row containing the stats for an individual rookie
#each player stored in tr, player element stored in td (html syntax)
playerRowHTML = page_soup.findAll('tr')[2:]
playerRows = [ [val.getText() for val in playerRowHTML[i].findAll('td')] for i in range(len(playerRowHTML)) ]

# %%
pd.set_option('display.max_columns', None)
rookiesRaw = pd.DataFrame(playerRows, columns=headers) #create dataframe
rookiesRaw.head()
# Out:
#   Pk   Tm           Player       College Yrs   G    MP   PTS  TRB  AST   FG%  \
# 0  1  NOP  Zion Williamson          Duke   1  19   565   448  129   41  .589
# 1  2  MEM        Ja Morant  Murray State   1  59  1771  1041  208  409  .491
# 2  3  NYK       RJ Barrett          Duke   1  56  1704   803  279  143  .402
# 3  4  LAL  De'Andre Hunter      Virginia   1  63  2018   778  286  112  .410
# 4  5  CLE   Darius Garland    Vanderbilt   1  59  1824   728  111  229  .401
#
#     3P%   FT%    MP   PTS  TRB  AST    WS  WS/48   BPM  VORP
# 0  .462  .645  29.7  23.6  6.8  2.2   1.8   .149   2.4   0.6
# 1  .367  .770  30.0  17.6  3.5  6.9   3.4   .093   0.4   1.1
# 2  .320  .614  30.4  14.3  5.0  2.6  -0.5  -.015  -4.3  -1.0
# 3  .355  .764  32.0  12.3  4.5  1.8   0.1   .001  -4.7  -1.4
# 4  .355  .875  30.9  12.3  1.9  3.9  -1.3  -.035  -5.6  -1.7

# %%
namesBefore = [x for x in rookiesRaw['Player']] #create a list of player names (will be useful for duplicate removal later)
rookies = rookiesRaw 
rookies.describe() #describe dataframe
# Out:
#         Pk   Tm                 Player College Yrs   G  MP PTS TRB AST FG%  \
# count   60   60                     60      60  60  60  60  60  60  60  60
# unique  60   28                     60      38   2  33  50  47  47  39  44
# top     39  PHI  Justin Wright-Foreman           1
# freq     1    5                      1       8  53   7   7   7   7   7   9
#
#        3P% FT%  MP PTS TRB  AST   WS WS/48 BPM VORP
# count   60  60  60  60  60   60   60    60  60   60
# unique  42  42  50  42  34   28   26    53  44   19
# top                         0.5  0.0            0.0
# freq    11  17   7   7   7    7    8     7   7   13

# %% [markdown]
# ## Clean Dataset (Missing Values, Column Names, etc.)

# %% [markdown]
# Update some redundant column names

# %%
#changed aggregated statistics by adding a 'T' to their header name
headers = ['Pk', 'Tm', 'Player', 'College', 'Yrs', 'GP', 'TMP', 'TPTS', 'TRB', 'TAST', 'FG%', '3P%', 'FT%', 'MP', 'PTS', 'RB', 'AST', 'WS', 'WS/48', 'BPM', 'VORP']
rookies.columns = headers

# %%
rookies.head()
# Out:
#   Pk   Tm           Player       College Yrs  GP   TMP  TPTS  TRB TAST   FG%  \
# 0  1  NOP  Zion Williamson          Duke   1  19   565   448  129   41  .589
# 1  2  MEM        Ja Morant  Murray State   1  59  1771  1041  208  409  .491
# 2  3  NYK       RJ Barrett          Duke   1  56  1704   803  279  143  .402
# 3  4  LAL  De'Andre Hunter      Virginia   1  63  2018   778  286  112  .410
# 4  5  CLE   Darius Garland    Vanderbilt   1  59  1824   728  111  229  .401
#
#     3P%   FT%    MP   PTS   RB  AST    WS  WS/48   BPM  VORP
# 0  .462  .645  29.7  23.6  6.8  2.2   1.8   .149   2.4   0.6
# 1  .367  .770  30.0  17.6  3.5  6.9   3.4   .093   0.4   1.1
# 2  .320  .614  30.4  14.3  5.0  2.6  -0.5  -.015  -4.3  -1.0
# 3  .355  .764  32.0  12.3  4.5  1.8   0.1   .001  -4.7  -1.4
# 4  .355  .875  30.9  12.3  1.9  3.9  -1.3  -.035  -5.6  -1.7

# %% [markdown]
# Set Draft Pick as Index and Drop 'Yrs' Column

# %%
rookies.set_index('Pk', inplace = True)

# %%
rookies.drop('Yrs', axis =1, inplace=True)

# %% [markdown]
# Cast to Numbers

# %%
categoricalVals = ['Tm', 'Player', 'College']
allVals = rookies.columns
numericalVals = list(set(allVals) - set(categoricalVals))
print(numericalVals)

for val in numericalVals:
    rookies[val] = pd.to_numeric(rookies[val], downcast='float')
# Out:
# ['VORP', 'FG%', 'AST', 'TMP', 'BPM', 'TPTS', 'FT%', 'RB', 'PTS', 'WS/48', 'TRB', 'MP', 'WS', 'GP', '3P%', 'TAST']

# %% [markdown]
# Check for Missing Values

# %%
# given the null values present, we must get rid of them (remember earlier function from module 1)

def assess_NA(data):
    # pandas series denoting features and the sum of their null values
    null_sum = data.isnull().sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(data.index))*100).round(2) ).sort_values(ascending=False)

    #concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    return df_NA
print('Before Dropping any Rows:')
assess = assess_NA(rookies)
assess
# Out:
# Before Dropping any Rows:
#          Number of NA  Percent NA
# FT%                19       30.65
# 3P%                13       20.97
# FG%                11       17.74
# BPM                 9       14.52
# GP                  9       14.52
# TMP                 9       14.52
# TPTS                9       14.52
# TRB                 9       14.52
# TAST                9       14.52
# VORP                9       14.52
# MP                  9       14.52
# PTS                 9       14.52
# RB                  9       14.52
# AST                 9       14.52
# WS                  9       14.52
# WS/48               9       14.52
# College             2        3.23
# Player              2        3.23
# Tm                  2        3.23

# %%
rookies.dropna(axis=0, how = 'any', thresh=None, inplace =True)
rookies.describe()
# Out:
#               GP          TMP         TPTS         TRB        TAST        FG%  \
# count  42.000000    42.000000    42.000000   42.000000   42.000000  42.000000
# mean   39.452381   801.214294   329.976196  125.071426   66.690475   0.431619
# std    19.520100   616.678406   292.992432   96.251038   75.844666   0.090713
# min     4.000000    11.000000     4.000000    5.000000    0.000000   0.200000
# 25%    21.000000   276.500000    72.500000   33.250000   16.000000   0.385500
# 50%    47.500000   733.500000   238.000000  114.500000   46.000000   0.415500
# 75%    56.750000  1259.750000   572.000000  205.500000   94.000000   0.476750
# max    65.000000  2018.000000  1041.000000  316.000000  409.000000   0.660000
#
#              3P%        FT%         MP        PTS         RB        AST  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    0.281738   0.732310  17.388094   7.192857   2.816667   1.407143
# std     0.107272   0.132521   8.776637   5.112844   1.591428   1.200689
# min     0.000000   0.462000   2.800000   1.000000   0.600000   0.000000
# 25%     0.234750   0.645250  10.125000   3.500000   1.500000   0.525000
# 50%     0.298500   0.738500  17.100000   4.850000   2.800000   1.150000
# 75%     0.354750   0.801500  25.324999  11.625000   3.700000   1.875000
# max     0.462000   1.000000  32.000000  23.600000   6.800000   6.900000
#
#               WS      WS/48        BPM       VORP
# count  42.000000  42.000000  42.000000  42.000000
# mean    0.669048   0.046333  -3.178571  -0.164286
# std     1.178359   0.064483   3.913425   0.606397
# min    -1.300000  -0.109000 -21.299999  -1.700000
# 25%     0.025000   0.001500  -4.525000  -0.300000
# 50%     0.250000   0.050500  -3.150000  -0.100000
# 75%     0.975000   0.080250  -1.075000   0.000000
# max     4.400000   0.192000   3.500000   1.500000

# %%
assess = assess_NA(rookies)
assess
# Out:
#          Number of NA  Percent NA
# VORP                0         0.0
# FG%                 0         0.0
# Player              0         0.0
# College             0         0.0
# GP                  0         0.0
# TMP                 0         0.0
# TPTS                0         0.0
# TRB                 0         0.0
# TAST                0         0.0
# 3P%                 0         0.0
# BPM                 0         0.0
# FT%                 0         0.0
# MP                  0         0.0
# PTS                 0         0.0
# RB                  0         0.0
# AST                 0         0.0
# WS                  0         0.0
# WS/48               0         0.0
# Tm                  0         0.0

# %% [markdown]
# Join Position Data to the Rookies Dataset

# %%
import pandas as pd 
allplayers=pd.read_csv('./data/NBAplayerTotals2020.csv')
allplayers.head()
# Out:
#                      Player Pos   Age   Tm     G    GS      MP     FG    FGA  \
# 0              Steven Adams   C  26.0  OKC  58.0  58.0  1564.0  262.0  443.0
# 1               Bam Adebayo  PF  22.0  MIA  65.0  65.0  2235.0  408.0  719.0
# 2         LaMarcus Aldridge   C  34.0  SAS  53.0  53.0  1754.0  391.0  793.0
# 3  Nickeil Alexander-Walker  SG  21.0  NOP  41.0   0.0   501.0   77.0  227.0
# 4             Grayson Allen  SG  24.0  MEM  30.0   0.0   498.0   79.0  176.0
#
#      FG%    3P    3PA    3P%     2P    2PA    2P%   eFG%     FT    FTA    FT%  \
# 0  0.591   1.0    3.0  0.333  261.0  440.0  0.593  0.593  108.0  183.0  0.590
# 1  0.567   1.0   13.0  0.077  407.0  706.0  0.576  0.568  236.0  342.0  0.690
# 2  0.493  61.0  157.0  0.389  330.0  636.0  0.519  0.532  158.0  191.0  0.827
# 3  0.339  40.0  117.0  0.342   37.0  110.0  0.336  0.427   17.0   28.0  0.607
# 4  0.449  33.0   91.0  0.363   46.0   85.0  0.541  0.543   30.0   35.0  0.857
#
#      ORB    DRB    TRB    AST   STL   BLK    TOV     PF     PTS   TS%    PER  \
# 0  196.0  347.0  543.0  141.0  50.0  65.0   86.0  111.0   633.0  0.60  19.40
# 1  165.0  518.0  683.0  333.0  78.0  85.0  185.0  164.0  1053.0  0.61  18.42
# 2  103.0  289.0  392.0  129.0  36.0  87.0   74.0  128.0  1001.0  0.57  18.39
# 3    8.0   72.0   80.0   74.0  11.0   7.0   40.0   46.0   211.0  0.44   8.87
# 4    5.0   61.0   66.0   43.0   6.0   1.0   23.0   36.0   221.0  0.58  11.41
#
#        VA  EWA
# 0  205.42  6.8
# 1  230.84  7.7
# 2  203.94  6.8
# 3  -12.19 -0.4
# 4    6.76  0.2

# %%
positions = allplayers[['Player', 'Pos', 'eFG%']]
positions.head()
# Out:
#                      Player Pos   eFG%
# 0              Steven Adams   C  0.593
# 1               Bam Adebayo  PF  0.568
# 2         LaMarcus Aldridge   C  0.532
# 3  Nickeil Alexander-Walker  SG  0.427
# 4             Grayson Allen  SG  0.543

# %%
rookies = pd.merge(rookies, positions, on = 'Player')
#run the above line only once

# %% [markdown]
# We were able to perform some initial EDA with the metrics above, but wanted to add more variables to our analysis of rookies.

# %% [markdown]
# ## Adding More Features (Scraping)

# %%
page_url = 'https://www.basketball-reference.com/leagues/NBA_2020_rookies-season-stats.html'

# opens the connection and downloads html page from url
uClient = urlopen(page_url)


# parses html into a soup data structure to traverse html as if it were a json data type.
page_soup = BeautifulSoup(uClient.read())
uClient.close()

# use findALL() to get the column headers
headerRowHTML = page_soup.findAll('tr', limit =3)

# %%
# use getText()to extract the text we need into a list
headers = [th.getText() for th in page_soup.findAll('tr', limit=2)[1].findAll('th')]

# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]

# %%
#list comprehension creates list of lists with each inner row containing the stats for an individual rookie
#each player stored in tr, player element stored in td (html syntax)
playerRowHTML = page_soup.findAll('tr')[2:]
playerRows = [ [val.getText() for val in playerRowHTML[i].findAll('td')] for i in range(len(playerRowHTML)) ]

# %%
pd.set_option('display.max_columns', None)
updateRaw = pd.DataFrame(playerRows, columns=headers) #create dataframe
updateRaw.head()
# Out:
#                      Player                    Debut Age Yrs   G    MP   FG  \
# 0  Nickeil Alexander-Walker   Oct 22, '19, NOP @ TOR  21   1  41   501   77
# 1                RJ Barrett   Oct 23, '19, NYK @ SAS  19   1  56  1704  292
# 2             Darius Bazley   Oct 23, '19, OKC @ UTA  19   1  53   909   88
# 3              Goga Bitadze   Oct 26, '19, IND @ CLE  20   1  49   410   61
# 4            Marques Bolden  Feb 1, '20, CLE vs. GSW  21   1   1     3    0
#
#    FGA  3P  3PA   FT  FTA ORB  TRB  AST STL BLK  TOV   PF  PTS   FG%   3P%  \
# 0  227  40  117   17   28   8   80   74  11   7   40   46  211  .339  .342
# 1  727  63  197  156  254  50  279  143  55  17  124  122  803  .402  .320
# 2  230  30  100   32   47  21  196   29  20  35   40   45  238  .383  .300
# 3  129   6   36   24   33  22   96   21   6  32   25   57  152  .473  .167
# 4    0   0    0    0    0   0    2    0   1   0    0    1    0
#
#     FT%    MP   PTS  TRB  AST
# 0  .607  12.2   5.1  2.0  1.8
# 1  .614  30.4  14.3  5.0  2.6
# 2  .681  17.2   4.5  3.7  0.5
# 3  .727   8.4   3.1  2.0  0.4
# 4         3.0   0.0  2.0  0.0

# %%
#drop the data we do not need
list(rookies.columns)
# Out:
# ['Tm',
#  'Player',
#  'College',
#  'GP',
#  'TMP',
#  'TPTS',
#  'TRB',
#  'TAST',
#  'FG%',
#  '3P%',
#  'FT%',
#  'MP',
#  'PTS',
#  'RB',
#  'AST',
#  'WS',
#  'WS/48',
#  'BPM',
#  'VORP',
#  'Pos',
#  'eFG%']

# %%
updateRaw.drop(['G','MP','FG%','3P%','PTS','TRB','AST','FT%','Yrs'], axis = 1, inplace=True)
updateRaw.head()
# Out:
#                      Player                    Debut Age   FG  FGA  3P  3PA  \
# 0  Nickeil Alexander-Walker   Oct 22, '19, NOP @ TOR  21   77  227  40  117
# 1                RJ Barrett   Oct 23, '19, NYK @ SAS  19  292  727  63  197
# 2             Darius Bazley   Oct 23, '19, OKC @ UTA  19   88  230  30  100
# 3              Goga Bitadze   Oct 26, '19, IND @ CLE  20   61  129   6   36
# 4            Marques Bolden  Feb 1, '20, CLE vs. GSW  21    0    0   0    0
#
#     FT  FTA ORB STL BLK  TOV   PF
# 0   17   28   8  11   7   40   46
# 1  156  254  50  55  17  124  122
# 2   32   47  21  20  35   40   45
# 3   24   33  22   6  32   25   57
# 4    0    0   0   1   0    0    1

# %%
namesBefore = [x for x in rookiesRaw['Player']] #create a list of player names (will be useful for duplicate removal later)
update = updateRaw 
update.describe() #describe dataframe
# Out:
#                           Player                   Debut  Age   FG  FGA   3P  \
# count                        115                     115  115  115  115  115
# unique                       115                      90   10   66   81   43
# top     Nickeil Alexander-Walker  Oct 23, '19, WAS @ DAL   22    0    5    0
# freq                           1                       4   29   14    8   39
#
#         3PA   FT  FTA  ORB  STL  BLK  TOV   PF
# count   115  115  115  115  115  115  115  115
# unique   59   47   54   42   37   32   47   63
# top       1    0    0    0    0    0    0    0
# freq     12   27   24   28   26   33   19   12

# %%
categoricalVals = ['Player', 'Debut']
allVals = update.columns
numericalVals = list(set(allVals) - set(categoricalVals))

for val in numericalVals:
    update[val] = pd.to_numeric(update[val], downcast='float')

# %%
print('Before Dropping any Rows:')
assess = assess_NA(update)
assess
# Out:
# Before Dropping any Rows:
#         Number of NA  Percent NA
# PF                10         8.0
# TOV               10         8.0
# BLK               10         8.0
# STL               10         8.0
# ORB               10         8.0
# FTA               10         8.0
# FT                10         8.0
# 3PA               10         8.0
# 3P                10         8.0
# FGA               10         8.0
# FG                10         8.0
# Age               10         8.0
# Debut             10         8.0
# Player            10         8.0

# %%
update.dropna(axis=0, how = 'any', thresh=None, inplace =True)
update.describe()
# Out:
#               Age          FG         FGA          3P         3PA          FT  \
# count  115.000000  115.000000  115.000000  115.000000  115.000000  115.000000
# mean    22.060869   62.878262  142.834778   18.121738   54.330433   24.000000
# std      2.005637   92.156822  208.787979   30.150543   84.853821   37.605289
# min     19.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     20.500000    2.500000    7.500000    0.000000    2.000000    1.000000
# 50%     22.000000   19.000000   36.000000    3.000000   11.000000    7.000000
# 75%     23.000000   87.500000  195.500000   21.500000   75.500000   31.500000
# max     29.000000  393.000000  850.000000  133.000000  376.000000  204.000000
#
#               FTA         ORB         STL         BLK         TOV          PF
# count  115.000000  115.000000  115.000000  115.000000  115.000000  115.000000
# mean    33.347828   15.660870   12.513043    7.652174   23.173914   38.626087
# std     52.183891   20.979893   17.271498   11.816613   35.216438   45.897572
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    1.000000    1.000000    0.000000    1.000000    2.500000
# 50%     10.000000    6.000000    4.000000    2.000000    7.000000   16.000000
# 75%     45.000000   21.500000   19.500000    9.000000   33.000000   72.000000
# max    265.000000   82.000000   80.000000   56.000000  191.000000  182.000000

# %%
assess = assess_NA(update)
assess
# Out:
#         Number of NA  Percent NA
# PF                 0         0.0
# TOV                0         0.0
# BLK                0         0.0
# STL                0         0.0
# ORB                0         0.0
# FTA                0         0.0
# FT                 0         0.0
# 3PA                0         0.0
# 3P                 0         0.0
# FGA                0         0.0
# FG                 0         0.0
# Age                0         0.0
# Debut              0         0.0
# Player             0         0.0

# %% [markdown]
# ## Join the New Dataset to the Original

# %%
rookies = pd.merge(rookies, update, on = 'Player')
#run the above line only once
rookies.head()
# Out:
#     Tm           Player       College    GP     TMP    TPTS    TRB   TAST  \
# 0  NOP  Zion Williamson          Duke  19.0   565.0   448.0  129.0   41.0
# 1  MEM        Ja Morant  Murray State  59.0  1771.0  1041.0  208.0  409.0
# 2  NYK       RJ Barrett          Duke  56.0  1704.0   803.0  279.0  143.0
# 3  LAL  De'Andre Hunter      Virginia  63.0  2018.0   778.0  286.0  112.0
# 4  CLE   Darius Garland    Vanderbilt  59.0  1824.0   728.0  111.0  229.0
#
#      FG%    3P%    FT%         MP   PTS   RB  AST   WS  WS/48  BPM  VORP Pos  \
# 0  0.589  0.462  0.645  29.700001  23.6  6.8  2.2  1.8  0.149  2.4   0.6  PF
# 1  0.491  0.367  0.770  30.000000  17.6  3.5  6.9  3.4  0.093  0.4   1.1  PG
# 2  0.402  0.320  0.614  30.400000  14.3  5.0  2.6 -0.5 -0.015 -4.3  -1.0  SG
# 3  0.410  0.355  0.764  32.000000  12.3  4.5  1.8  0.1  0.001 -4.7  -1.4  SF
# 4  0.401  0.355  0.875  30.900000  12.3  1.9  3.9 -1.3 -0.035 -5.6  -1.7  PG
#
#     eFG%                     Debut   Age     FG    FGA     3P    3PA     FT  \
# 0  0.599  Jan 22, '20, NOP vs. SAS  19.0  172.0  292.0    6.0   13.0   98.0
# 1  0.523    Oct 23, '19, MEM @ MIA  20.0  393.0  800.0   51.0  139.0  204.0
# 2  0.445    Oct 23, '19, NYK @ SAS  19.0  292.0  727.0   63.0  197.0  156.0
# 3  0.489    Oct 24, '19, ATL @ DET  22.0  280.0  683.0  108.0  304.0  110.0
# 4  0.476    Oct 23, '19, CLE @ ORL  20.0  280.0  699.0  105.0  296.0   63.0
#
#      FTA   ORB   STL   BLK    TOV     PF
# 0  152.0  55.0  16.0   9.0   51.0   32.0
# 1  265.0  44.0  54.0  15.0  191.0   90.0
# 2  254.0  50.0  55.0  17.0  124.0  122.0
# 3  144.0  44.0  44.0  18.0  103.0  182.0
# 4   72.0  27.0  42.0   4.0  151.0   92.0

# %%
rookies = rookies[['Player','College','Pos','Tm', 'GP', 'TMP', 'TPTS','TRB','ORB','TAST', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA','FT%','STL','BLK', 'TOV', 'PF', 'MP','PTS', 'RB','AST', 'WS', 'WS/48', 'BPM', 'VORP']]
rookies.head()
# Out:
#             Player       College Pos   Tm    GP     TMP    TPTS    TRB   ORB  \
# 0  Zion Williamson          Duke  PF  NOP  19.0   565.0   448.0  129.0  55.0
# 1        Ja Morant  Murray State  PG  MEM  59.0  1771.0  1041.0  208.0  44.0
# 2       RJ Barrett          Duke  SG  NYK  56.0  1704.0   803.0  279.0  50.0
# 3  De'Andre Hunter      Virginia  SF  LAL  63.0  2018.0   778.0  286.0  44.0
# 4   Darius Garland    Vanderbilt  PG  CLE  59.0  1824.0   728.0  111.0  27.0
#
#     TAST     FG    FGA    FG%     3P    3PA    3P%     FT    FTA    FT%   STL  \
# 0   41.0  172.0  292.0  0.589    6.0   13.0  0.462   98.0  152.0  0.645  16.0
# 1  409.0  393.0  800.0  0.491   51.0  139.0  0.367  204.0  265.0  0.770  54.0
# 2  143.0  292.0  727.0  0.402   63.0  197.0  0.320  156.0  254.0  0.614  55.0
# 3  112.0  280.0  683.0  0.410  108.0  304.0  0.355  110.0  144.0  0.764  44.0
# 4  229.0  280.0  699.0  0.401  105.0  296.0  0.355   63.0   72.0  0.875  42.0
#
#     BLK    TOV     PF         MP   PTS   RB  AST   WS  WS/48  BPM  VORP
# 0   9.0   51.0   32.0  29.700001  23.6  6.8  2.2  1.8  0.149  2.4   0.6
# 1  15.0  191.0   90.0  30.000000  17.6  3.5  6.9  3.4  0.093  0.4   1.1
# 2  17.0  124.0  122.0  30.400000  14.3  5.0  2.6 -0.5 -0.015 -4.3  -1.0
# 3  18.0  103.0  182.0  32.000000  12.3  4.5  1.8  0.1  0.001 -4.7  -1.4
# 4   4.0  151.0   92.0  30.900000  12.3  1.9  3.9 -1.3 -0.035 -5.6  -1.7

# %% [markdown]
# ### Adding True Shooting %, Player Efficiency Rating, Value Added, and Estimated Wins Added

# %%
playersTS = rookies['PTS'] / (2 * ( rookies['FGA'] + 0.44*rookies['FTA'] ))
rookies['TS%'] =  playersTS.round(decimals=2)

# %%
PER_coeff = {
    "FG": 85.910,
    "STL": 53.897,
    "3P": 51.757,
    "FT": 46.845,
    "BLK": 39.190,
    "ORB": 39.190,
    "AST": 34.677,
    "DRB": 14.707,
    "PF": -17.174,
    "FTmiss": -20.091,
    "FGmiss": -39.190,
    "TOV": -53.897
}

rookies["DRB"] = rookies["TRB"] - rookies["ORB"]
# adding defensive rebounds column

playerER = (
    rookies["FG"]*PER_coeff["FG"] + 
    rookies["STL"]*PER_coeff["STL"] + 
    rookies["3P"]*PER_coeff["3P"] + 
    rookies["BLK"]*PER_coeff["BLK"] + 
    rookies["ORB"]*PER_coeff["ORB"] + 
    rookies["AST"]*PER_coeff["AST"] + 
    rookies["DRB"]*PER_coeff["DRB"] + 
    rookies["PF"]*PER_coeff["PF"] + 
    (rookies["FGA"]-rookies["FG"])*PER_coeff["FGmiss"] + 
    (rookies["FTA"]-rookies["FT"])*PER_coeff["FTmiss"] + 
    rookies["TOV"]*PER_coeff["TOV"]
)

playerER *= (1 / rookies["MP"])

playerER = playerER.round(decimals=2)

rookies['PER'] = playerER

# %%
VA_coeff = {
    'PF':11.5,
    'PG':11.0,
    'C':10.6,
    'SF':10.5,
    'SG':10.5
}

PRL = [ VA_coeff[pos] for pos in rookies['Pos']]

playerVA = (rookies['MP'] * (rookies['PER'] - PRL)) / 67
playerVA = playerVA.round(decimals=2)

playerEWA = playerVA/30
playerEWA = playerEWA.round(decimals=1)

rookies['VA'] = playerVA
rookies['EWA'] = playerEWA

# %% [markdown]
# Now that the data set is complete, we can export it as a CSV to be used in our model file

# %%
out_filename = "NBArookies2019.csv"
rookies.to_csv(out_filename, index=False, header = True)
